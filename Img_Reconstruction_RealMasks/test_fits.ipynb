# %%
import numpy as np
from astropy.io import fits
from pathlib import Path
import mbloodmoon as bm

# %%
root_path = "/mnt/d/PhD_AASS/Coding/Images_fits/"
filepath = root_path + "test_IROS_output1.fits"

# %%
with fits.open(filepath) as hdu:
    hduA = dict(hdu[1].header)
    hduB = dict(hdu[2].header)
    print(hduA)
    #print(f"{hduA['EXTNAME'].lower(), hduB['EXTNAME'].lower()}")
    hduA_data = hdu[1].data
    #print(len(hduA_data[0]))
    #print(hduA_data.field(0))
    #print(hduA_data)
# Out:
# {'XTENSION': 'BINTABLE', 'BITPIX': 8, 'NAXIS': 2, 'NAXIS1': 96, 'NAXIS2': 5, 'PCOUNT': 0, 'GCOUNT': 1, 'TFIELDS': 13, 'COMMENT':   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# ...
